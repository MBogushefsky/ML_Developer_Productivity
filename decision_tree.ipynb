# %% [markdown]
# <a href="https://colab.research.google.com/github/MBogushefsky/ML_Developer_Productivity/blob/main/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import tree

# %%
df = pd.read_csv('./ai_dev_productivity.csv')

# %%
X = df.drop('task_success', axis=1)
y = df['task_success']
dtc = tree.DecisionTreeClassifier()
dtc.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
X.head()
# Out:
#    hours_coding  coffee_intake_mg  distractions  sleep_hours  commits  \
# 0          5.99               600             1          5.8        2
# 1          4.72               568             2          6.9        5
# 2          6.30               560             1          8.9        2
# 3          8.05               600             7          6.3        9
# 4          4.53               421             6          6.9        4
#
#    bugs_reported  ai_usage_hours  cognitive_load
# 0              1            0.71             5.4
# 1              3            1.75             4.7
# 2              0            2.27             2.2
# 3              5            1.40             5.9
# 4              0            1.26             6.3

# %%
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
